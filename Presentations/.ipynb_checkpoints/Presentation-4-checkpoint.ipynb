# %% [markdown]
# # Research Quesiton: Exploring Cross Polytopes by Transforming Samples from the Canonical Simplex to the l1-Ball.

# %% [markdown]
# We define the canonical simplex $\Omega^n$ living in $\mathbb{R}^{n}$ as
# $$
# \Omega^n = \{(x_0,\dots,x_{n-1}) \in \mathbb{R}^{n} : x_0 + \dots + x_{n-1} \leq 1 \; \text{and} \; x_i \ge 0 \; \forall \, i\}.
# $$
#
# For $n=2$,
#
# $$
# \Omega^2 = \{(x_0,x_1) \in \mathbb{R}^{2} : x_0 + x_{1} \leq 1 \; \text{and} \; x_i \ge 0 \; \forall \, i\}.
# $$

# %% [markdown]
# Generating m samples that are Uniform in $\Omega^n$ is quite fun with a small algorithm as follows:
#
# For i=1 to m:
#
#     1.) Pick a point u uniform in (0,1).
#     2.) Add u to the list l containing elements 0 and 1.
#     3.) Sort l in ascending order.
#     For j=1 to n:
#         -Set the vector v[j-1] = l[j] - l[j-1].
#     4.) Append the vector v to the set of samples uniform in the canonical simplex
# Output: m samples uniform in $\Omega^n$

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

n = 3
samples = 10000
S = np.zeros((n,1))
verbose = False
#Uniform samples from the n-dimensional simplex 
for i in range(samples):
    U = np.random.uniform(0,1,n-1)
    if(verbose):
        print("U(0,1) with n = 2:")
        print(U)
        print("")
    tmp = np.array([0, 1])
    Final = np.zeros(n)
    U = np.hstack((U,tmp))
    if(verbose):
        print("Append the x and y to the list of 0 and 1:")
        print(U)
        print("")
    U = np.sort(U)
    if(verbose):
        print("Now sort the list in ascending order:")
        print(U)
        print("")
    for i in range(1,n+1):
        if(verbose):
            print(f"Iteration {i}:")
            print(f"Subracting {U[i]} - {U[i-1]} = {U[i] - U[i-1]}")
        Final[i-1] = U[i] - U[i-1]
        if(verbose):
            print(f"Final[{i-1}] = {U[i] - U[i-1]}")
            print(Final)
            print("")
    if(verbose):
        print("A point Uniform in the canonical n-simplex: ")
        print(Final)
        print("----------------------------------------------------------\n")
    S = np.hstack((S, np.reshape(Final, (n,1))))
S = np.delete(S, 0,1)

# %%
plt.plot(S[0,:], S[1,:], "bo", markersize=.2);

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(S[0,:], S[1,:], S[2, :], "bo")

# %% [markdown]
# If we compare the definition of $\Omega^n$ to the definition of the $\ell_1$ norm:
#
# $$
# \Omega^n = \{(x_0,\dots,x_{n-1}) \in \mathbb{R}^{n} : x_0 + \dots + x_{n-1} \leq 1 \; \text{and} \; x_i \ge 0 \; \forall \, i\}.
# $$
#
# $$
# \| x\|_1 = \sum_{i=1}^\infty |x_i|
# $$
#
# Now, lets bound this to be
#
# $$
# \| x\|_1 \leq 1
# $$
#
# The $x_i \in \Omega^n$ are restricted to quadrant 1, but the $x_i \in \| x\|_1$ can exist in any quadrant.
#
# So, how can we perserve uniformity and allow the points in $\Omega^n$ to exist in any quadrant?
#
# We can simulate a coin flip using the binomial distribution, and depending on heads or tails flip the sign.

# %%
for i in range(S.shape[1]):
    binom = np.random.binomial(1,.5)
    if(binom == 1):
        S[0][i] = S[0][i]*(-1)

# %%
plt.plot(S[0,:], S[1,:], "bo");

# %%
for i in range(S.shape[1]):
    binom = np.random.binomial(1,.5)
    if(binom == 1):
        S[1][i] = S[1][i]*(-1)

# %%
plt.plot(S[0,:], S[1,:], "bo");

# %% [markdown]
# m samples in the $\ell_1$-ball are pictured above, what clever calculus 2 strategy could we use to calculate the volume (in our 2-D case area) of this object?

# %% [markdown]
# Well, we notice there is a familiar function that when plotted appears like the bottom of the $\ell_1$-ball.
#
# $$
# f(x) = |x|
# $$

# %%
x = np.linspace(-1,1)
y = abs(x)
plt.plot(x, y);

# %% [markdown]
# We need to shift this function down by one unit, so f(x) is defined as
# $$
# f(x) = |x| - 1
# $$

# %%
x = np.linspace(-1,1)
y = abs(x)
plt.plot(x, y);
x_ = np.linspace(-1,1)
y_ = abs(x_) -1
plt.plot(x_, y_);

# %% [markdown]
# Now that we have the bottom, lets get the top.  We need to essentially negate $f(x)$ and let $g(x) = -|x|$ and then shift this line up by one unit.

# %% [markdown]
# $$
# g(x) = -|x| + 1
# $$

# %%
x = np.linspace(-1,1)
y = -abs(x) + 1
plt.plot(x, y);
x_ = np.linspace(-1,1)
y_ = abs(x_) -  1
plt.plot(x_, y_);

# %% [markdown]
# If we are to plot both the samples and these two functions together, we arrive at the following:

# %%
plt.plot(S[0,:], S[1,:], "bo");
plt.plot(x, y, linewidth=2.0, color="r");
plt.plot(x_, y_, linewidth=2.0, color="r" );

# %% [markdown]
# From calculus if we have two functions $f(x)$ and $g(x)$ and we would like to find the volume (area in 2-D), we can integrate the upper - lower.
#
# \begin{align*}
# \int_{-1}^{1} - |x| + 1 - |x| + 1 \; dx &=  \int_{-1}^{1} - 2|x| + 2 \; dx\\
# &= \int_{-1}^{1} - 2|x| + 2 \; dx\\
# &= -2\int_{-1}^{1} |x| \; dx + \int_{-1}^{1}2 \; dx\\
# &= -2\left[\frac{x|x|}{2}\right]_{-1}^{1}  + \; [2x]_{-1}^{1} \\
# &= -2\left[\frac{(1)|1|}{2} - \frac{(-1)|-1|}{2}\right] + 2 - (-2) \\
# &= -2\left[\frac{1}{2} + \frac{1}{2}\right] + 2 - (-2) \\
# &= -2 + 4 \\
# &= 2 \\
# \end{align*}

# %% [markdown]
# The formula for the volume of the $\ell_1$-ball is given as,
#
# $$
# \frac{2^n}{n!}
# $$

# %% [markdown]
# The formula for the volume of the $\Omega^n$ is given as,
#
# $$
# \dfrac{1}{n!}
# $$
#
# The volume of the $\ell_1$-ball is formed from the fact that it has $2^n$ facets such that each facet is a $\Omega^n$.
# Therefore, we arrive at
#
# $$
# 2^n\left(\frac{1}{n!}\right).
# $$
#
# # Conclusion
#
# The family of convex shapes the $\ell_1^n$-ball forms is referred to as the cross polytopes.
#
# The cross polytopes are all constructed by $(n-1)$-simplices, in our case the canonical simplex $\Omega^n$.
#
#
# ## Food for thought:
# What connection does $\Omega^n$ have with $\ell_1$-ball in general or as n increases?  What might the geometry of the $\ell_1$-ball $\in \mathbb{R}^3$ or $\Omega^3$ appear like?
